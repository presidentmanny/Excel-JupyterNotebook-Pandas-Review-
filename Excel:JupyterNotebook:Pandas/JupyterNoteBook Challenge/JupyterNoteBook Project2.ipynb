# %%
# Dependencies
import pandas as pd

# %%
# load CSV
new_coders='2016-FCC-New-Coders-Survey-Data.csv'

# %%
# Read with pandas
# low_memory to get rid of error about mixed data type in some colums 
new_coders = pd.read_csv(new_coders, encoding = 'iso-8859-1', low_memory=False)
new_coders.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# ...

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111

reduced_coders_pd=new_coders.iloc[:,[0, 1, 2, 3, 4, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]

# %%
# Change reading 0 and 1 to No and Yes, respectively

reduced_coders_pd= reduced_coders_pd.replace({0.0: "No", 1.0: "Yes"})
reduced_coders_pd.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 0               NaN                 NaN               NaN            NaN
# 1               NaN                 NaN               NaN            NaN
# 2               NaN                 NaN               NaN            NaN
# 3               NaN                 NaN               NaN            NaN
# 4               NaN                 NaN               NaN            NaN
#
#                   CityPopulation CodeEventBootcamp               CountryLive  \
# 0  between 100,000 and 1 million               NaN  United States of America
# ...

# %%
# Extract rows for only those who attended a bootcamp
attended_bootcamp = reduced_coders_pd.loc[reduced_coders_pd["AttendedBootcamp"] == "Yes"]
attended_bootcamp.count()
# Out:
# Age                     818
# AttendedBootcamp        953
# BootcampFinish          933
# BootcampFullJobAfter    635
# BootcampLoanYesNo       934
# BootcampPostSalary      330
# BootcampRecommend       937
# ChildrenNumber          148
# CityPopulation          823
# CodeEventBootcamp        27
# CountryLive             825
# EmploymentField         476
# EmploymentStatus        792
# Gender                  833
# HasChildren             211
# HoursLearning           925
# Income                  430
# JobRoleInterest         402
# SchoolDegree            832
# SchoolMajor             622
# dtype: int64

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees
reduced_coders_pd['BootcampName']=new_coders['BootcampName']
boot_camps= reduced_coders_pd.loc[reduced_coders_pd["AttendedBootcamp"] == "Yes"]
boot_camps=boot_camps.BootcampName.value_counts()
boot_camps=pd.DataFrame(boot_camps)
boot_camps.reset_index(drop=False,inplace=True)
boot_camps.columns=['BootcampName','Count']
print(boot_camps.shape)
boot_camps.head()
# Out:
# (128, 2)
#             BootcampName  Count
# 0       General Assembly     90
# 1        Flatiron School     54
# 2           Dev Bootcamp     48
# 3          The Iron Yard     40
# 4  Prime Digital Academy     30

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp
recommend =reduced_coders_pd.loc[(reduced_coders_pd["AttendedBootcamp"] == "Yes")&(reduced_coders_pd["BootcampRecommend"] == "Yes")]
recommend=recommend.groupby('BootcampName').BootcampRecommend.count()

recommend=pd.DataFrame(recommend)
recommend.reset_index(drop=False,inplace=True)
print(recommend.shape)
recommend.head()
# Out:
# (116, 2)
#           BootcampName  BootcampRecommend
# 0           10x.org.il                  3
# 1       4Geeks Academy                  4
# 2             AcadGild                  2
# 3  Academia de CÃ³digo                  4
# 4                  Ada                  8

# %%
# Merge the two created data frames on the name of tbe bootcamp
merged_df=pd.merge(boot_camps,recommend,on='BootcampName')
merged_df.head()
# Out:
#             BootcampName  Count  BootcampRecommend
# 0       General Assembly     90                 70
# 1        Flatiron School     54                 50
# 2           Dev Bootcamp     48                 41
# 3          The Iron Yard     40                 31
# 4  Prime Digital Academy     30                 25

# %%
# Calculate percentage of eac bootcamp's students who are recommenders
merged_df['%Recommend']=100*merged_df['BootcampRecommend']/merged_df['Count']

# %%
#Sort the new DataFrame in descending order of the percentage of recommenders you just calculated.
merged_df.sort_values('%Recommend',ascending=False,inplace=True)

# %%
merged_df['%Recommend'] =merged_df['%Recommend'].map("{0:,.2f}%".format)
merged_df.head()
# Out:
#                                       BootcampName  Count  BootcampRecommend  \
# 115  Microsoft Research Data Science Summer School      1                  1
# 101                               CodeCraft School      1                  1
# 36                               Fullstack Academy      6                  6
# 99                               Founders & Coders      1                  1
# 98                         Science to Data Science      1                  1
#
#     %Recommend
# 115    100.00%
# 101    100.00%
# 36     100.00%
# 99     100.00%
# 98     100.00%

# %%
# Export to excel and remove index
merged_df.to_excel("Percent_Recommend.xlsx", index=False)
